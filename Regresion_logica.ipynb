# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/ASUS/Desktop/Analisis_de_Datos/Actividad2/dataset/framingham.csv", sep=",")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data[['age','TenYearCHD']].head()
# Out:
#    age  TenYearCHD
# 0   39           0
# 1   46           0
# 2   48           0
# 3   61           1
# 4   46           0

# %%
data[['age','TenYearCHD']].plot.scatter(x='age',y='TenYearCHD')
# Out:
# <Axes: xlabel='age', ylabel='TenYearCHD'>

# %%
w = 0.09
b = -3.6

# %%
x = np.linspace(0,data['age'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))

# %%
data.plot.scatter(x='age',y='TenYearCHD')
plt.plot(x, y, color='#000000')
plt.ylim(0,data['TenYearCHD'].max()*1.1)
plt.scatter(x, y, color='#FFFF00')
plt.grid()
plt.xlabel('Edad')
plt.ylabel('Riesgo de enfermedad coronaria a diez años 1:True 0:false')
plt.show()
